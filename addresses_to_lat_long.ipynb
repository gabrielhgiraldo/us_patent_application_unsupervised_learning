# %%
from pygeocoder import Geocoder
import pandas as pd
import numpy as np

# %%
assignments = pd.read_csv('data/us_pto_2017/assignment_sample.csv')

# %%
assignments.head()
# Out:
#        rf_id  file_id                    cname                    caddress_1  \
# 0  382930809       17       STAAS & HALSEY LLP      1201 NEW YORK AVE., N.W.
# 1  152210123        7  ALIX YALE & RISTAS, LLP        THOMAS J. MENARD, ESQ.
# 2  372400001       17             WENDY THOMAS  1299 PENNSYLVANIA, SUITE 700
# 3  435350335       18         SETTER ROCHE LLP         14694 ORCHARD PARKWAY
# 4  275750520       13    OBLON, SPIVAK, ET AL.              1940 DUKE STREET
#
#                            caddress_2               caddress_3 caddress_4  \
# 0                           SUITE 700     WASHINGTON, DC 20005        NaN
# 1                     750 MAIN STREET  HARTFORD, CT 06103-2721        NaN
# 2  PATENT DEPARTMENT/ATTN: MARK ROGEL     WASHINGTON, DC 20004        NaN
# 3               BUILDING A, SUITE 200    WESTMINSTER, CO 80023        NaN
# 4                ALEXANDRIA, VA 22314                      NaN        NaN
#
# ...

# %%
assignments['address'] = assignments['caddress_1'].astype(str)+" " + assignments['caddress_2'].astype(str)+ " " +assignments['caddress_3'].astype(str) + " "+assignments['caddress_4'].astype(str)

# %%
assignments.head()
# Out:
#        rf_id  file_id                    cname                    caddress_1  \
# 0  382930809       17       STAAS & HALSEY LLP      1201 NEW YORK AVE., N.W.
# 1  152210123        7  ALIX YALE & RISTAS, LLP        THOMAS J. MENARD, ESQ.
# 2  372400001       17             WENDY THOMAS  1299 PENNSYLVANIA, SUITE 700
# 3  435350335       18         SETTER ROCHE LLP         14694 ORCHARD PARKWAY
# 4  275750520       13    OBLON, SPIVAK, ET AL.              1940 DUKE STREET
#
#                            caddress_2               caddress_3 caddress_4  \
# 0                           SUITE 700     WASHINGTON, DC 20005        NaN
# 1                     750 MAIN STREET  HARTFORD, CT 06103-2721        NaN
# 2  PATENT DEPARTMENT/ATTN: MARK ROGEL     WASHINGTON, DC 20004        NaN
# 3               BUILDING A, SUITE 200    WESTMINSTER, CO 80023        NaN
# 4                ALEXANDRIA, VA 22314                      NaN        NaN
#
# ...

# %%
assignments['lat'],assignments['long'] = assignments['address'].apply(lambda x: Geocoder.geocode(x).coordinates)
# Out:
# ---------------------------------------------------------------------------
# GeocoderError                             Traceback (most recent call last)
# <ipython-input-20-bf4d4c1767ee> in <module>()
# ----> 1 assignments['lat'],assignments['long'] = assignments['address'].apply(lambda x: Geocoder.geocode(x).coordinates)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-20-bf4d4c1767ee> in <lambda>(x)
# ----> 1 assignments['lat'],assignments['long'] = assignments['address'].apply(lambda x: Geocoder.geocode(x).coordinates)
#
# ...

# %%
coordinates.coordinates
# Out:
# (38.9008735, -77.0286497)
